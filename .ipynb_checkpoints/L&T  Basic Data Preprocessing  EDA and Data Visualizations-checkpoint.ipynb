# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading and visualizing the data

# %%
df = pd.read_csv("C:/Users/Arif/Desktop/l&t/train.csv")

# %%
df.head()
# Out:
#    UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0    420825             50578       58400  89.55         67        22807
# 1    537409             47145       65550  73.23         67        22807
# 2    417566             53278       61360  89.63         67        22807
# 3    624493             57513       66113  88.48         67        22807
# 4    539055             52378       60300  88.39         67        22807
#
#    manufacturer_id  Current_pincode_ID Date.of.Birth Employment.Type  ...  \
# 0               45                1441      01-01-84        Salaried  ...
# 1               45                1502      31-07-85   Self employed  ...
# 2               45                1497      24-08-85   Self employed  ...
# 3               45                1501      30-12-93   Self employed  ...
# 4               45                1495      09-12-77   Self employed  ...
#
#   SEC.SANCTIONED.AMOUNT  SEC.DISBURSED.AMOUNT  PRIMARY.INSTAL.AMT  \
# ...

# %%
print("The dataset has %d rows" %df.shape[0])
print("The dataset has %d columns" %df.shape[1])
# Out:
# The dataset has 233154 rows
# The dataset has 41 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233154 entries, 0 to 233153
# Data columns (total 41 columns):
# UniqueID                               233154 non-null int64
# disbursed_amount                       233154 non-null int64
# asset_cost                             233154 non-null int64
# ltv                                    233154 non-null float64
# branch_id                              233154 non-null int64
# supplier_id                            233154 non-null int64
# manufacturer_id                        233154 non-null int64
# Current_pincode_ID                     233154 non-null int64
# Date.of.Birth                          233154 non-null object
# Employment.Type                        225493 non-null object
# DisbursalDate                          233154 non-null object
# State_ID                               233154 non-null int64
# Employee_code_ID                       233154 non-null int64
# ...

# %%
df.describe()
# Out:
#             UniqueID  disbursed_amount    asset_cost            ltv  \
# count  233154.000000     233154.000000  2.331540e+05  233154.000000
# mean   535917.573376      54356.993528  7.586507e+04      74.746530
# std     68315.693711      12971.314171  1.894478e+04      11.456636
# min    417428.000000      13320.000000  3.700000e+04      10.030000
# 25%    476786.250000      47145.000000  6.571700e+04      68.880000
# 50%    535978.500000      53803.000000  7.094600e+04      76.800000
# 75%    595039.750000      60413.000000  7.920175e+04      83.670000
# max    671084.000000     990572.000000  1.628992e+06      95.000000
#
#            branch_id    supplier_id  manufacturer_id  Current_pincode_ID  \
# count  233154.000000  233154.000000    233154.000000       233154.000000
# mean       72.936094   19638.635035        69.028054         3396.880247
# std        69.834995    3491.949566        22.141304         2238.147502
# ...

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Initial Null Check

# %%
df.isnull().sum()
# Out:
# UniqueID                                  0
# disbursed_amount                          0
# asset_cost                                0
# ltv                                       0
# branch_id                                 0
# supplier_id                               0
# manufacturer_id                           0
# Current_pincode_ID                        0
# Date.of.Birth                             0
# Employment.Type                        7661
# DisbursalDate                             0
# State_ID                                  0
# Employee_code_ID                          0
# MobileNo_Avl_Flag                         0
# Aadhar_flag                               0
# PAN_flag                                  0
# VoterID_flag                              0
# Driving_flag                              0
# Passport_flag                             0
# PERFORM_CNS.SCORE                         0
# PERFORM_CNS.SCORE.DESCRIPTION             0
# ...

# %% [markdown]
# We can see that there are some missing values in the Employment.Type column.

# %%
df['Employment.Type'].value_counts()
# Out:
# Self employed    127635
# Salaried          97858
# Name: Employment.Type, dtype: int64

# %% [markdown]
# We will add a new unemployed type in this feature.

# %%
df['Employment.Type'] = df['Employment.Type'].fillna('Missing')

# %%
df['Employment.Type'].value_counts()
# Out:
# Self employed    127635
# Salaried          97858
# Unemployed         7661
# Name: Employment.Type, dtype: int64

# %%
df.columns
# Out:
# Index(['UniqueID', 'disbursed_amount', 'asset_cost', 'ltv', 'branch_id',
#        'supplier_id', 'manufacturer_id', 'Current_pincode_ID', 'Date.of.Birth',
#        'Employment.Type', 'DisbursalDate', 'State_ID', 'Employee_code_ID',
#        'MobileNo_Avl_Flag', 'Aadhar_flag', 'PAN_flag', 'VoterID_flag',
#        'Driving_flag', 'Passport_flag', 'PERFORM_CNS.SCORE',
#        'PERFORM_CNS.SCORE.DESCRIPTION', 'PRI.NO.OF.ACCTS', 'PRI.ACTIVE.ACCTS',
#        'PRI.OVERDUE.ACCTS', 'PRI.CURRENT.BALANCE', 'PRI.SANCTIONED.AMOUNT',
#        'PRI.DISBURSED.AMOUNT', 'SEC.NO.OF.ACCTS', 'SEC.ACTIVE.ACCTS',
#        'SEC.OVERDUE.ACCTS', 'SEC.CURRENT.BALANCE', 'SEC.SANCTIONED.AMOUNT',
#        'SEC.DISBURSED.AMOUNT', 'PRIMARY.INSTAL.AMT', 'SEC.INSTAL.AMT',
#        'NEW.ACCTS.IN.LAST.SIX.MONTHS', 'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS',
#        'AVERAGE.ACCT.AGE', 'CREDIT.HISTORY.LENGTH', 'NO.OF_INQUIRIES',
#        'loan_default'],
#       dtype='object')

# %%
# ['UniqueID', 'supplier_id', 'Current_pincode_ID', 'DisbursalDate',
# 'Employee_code_ID']

# %%
# df['branch_id'] = df['branch_id'].astype('category')
# df['manufacturer_id'] = df['manufacturer_id'].astype('category')
# df['State_ID'] = df['State_ID'].astype('category')
# df['NEW.ACCTS.IN.LAST.SIX.MONTHS'] = df['NEW.ACCTS.IN.LAST.SIX.MONTHS'].astype('category')
# df['DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS'] = df['DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS']
# df['NO.OF_INQUIRIES'] = df['NO.OF_INQUIRIES'].astype('category')
# df['loan_default'] = df['loan_default'].astype('category')
# df['Employment.Type'] = df['Employment.Type'].astype('category')

# %% [markdown]
# Some attributes are categorical but they are in integer so we will convert them into categorical.

# %%
#Converting features to categorical columns

# %%
for col in ['UniqueID','Aadhar_flag', 'branch_id', 'Current_pincode_ID', 'Driving_flag',
            'Employee_code_ID', 'loan_default', 'manufacturer_id' , 
            'MobileNo_Avl_Flag', 'State_ID', 'State_ID', 'VoterID_flag',
            'PAN_flag', 'Passport_flag', 'PERFORM_CNS.SCORE.DESCRIPTION',
            'Employment.Type']:
    df[col] = df[col].astype('category')

# %% [markdown]
# Similarly, we need to convert the date time variables into its respective data type.

# %%
df['Date.of.Birth'] = pd.to_datetime(df['Date.of.Birth'])
df['DisbursalDate'] = pd.to_datetime(df['DisbursalDate'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233154 entries, 0 to 233153
# Data columns (total 41 columns):
# UniqueID                               233154 non-null category
# disbursed_amount                       233154 non-null int64
# asset_cost                             233154 non-null int64
# ltv                                    233154 non-null float64
# branch_id                              233154 non-null category
# supplier_id                            233154 non-null int64
# manufacturer_id                        233154 non-null category
# Current_pincode_ID                     233154 non-null category
# Date.of.Birth                          233154 non-null datetime64[ns]
# Employment.Type                        233154 non-null category
# DisbursalDate                          233154 non-null datetime64[ns]
# State_ID                               233154 non-null category
# Employee_code_ID                       233154 non-null category
# ...

# %% [markdown]
# ## Analyzing the Categorical Variable

# %%
df.describe(include=['category'])
# Out:
#         UniqueID  branch_id  manufacturer_id  Current_pincode_ID  \
# count     233154     233154           233154              233154
# unique    233154         82               11                6698
# top       671084          2               86                2578
# freq           1      13138           109534                1880
#
#        Employment.Type  State_ID  Employee_code_ID  MobileNo_Avl_Flag  \
# count           233154    233154            233154             233154
# unique               3        22              3270                  1
# top      Self employed         4              2546                  1
# freq            127635     44870               628             233154
#
#         Aadhar_flag  PAN_flag  VoterID_flag  Driving_flag  Passport_flag  \
# count        233154    233154        233154        233154         233154
# unique            2         2             2             2              2
# ...

# %%
df.select_dtypes(include=['category']).nunique()
# Out:
# UniqueID                         233154
# branch_id                            82
# manufacturer_id                      11
# Current_pincode_ID                 6698
# Employment.Type                       3
# State_ID                             22
# Employee_code_ID                   3270
# MobileNo_Avl_Flag                     1
# Aadhar_flag                           2
# PAN_flag                              2
# VoterID_flag                          2
# Driving_flag                          2
# Passport_flag                         2
# PERFORM_CNS.SCORE.DESCRIPTION        20
# loan_default                          2
# dtype: int64

# %%
# We will proceed to drop those variables that have too many categories. These will only add noise to the model.

# %%
# df=df.drop(['BRANCH_ID','CURRENT_PINCODE_ID','EMPLOYEE_CODE_ID','SUPPLIER_ID'],axis=1)

# %%
df.columns
# Out:
# Index(['UniqueID', 'disbursed_amount', 'asset_cost', 'ltv', 'branch_id',
#        'supplier_id', 'manufacturer_id', 'Current_pincode_ID', 'Date.of.Birth',
#        'Employment.Type', 'DisbursalDate', 'State_ID', 'Employee_code_ID',
#        'MobileNo_Avl_Flag', 'Aadhar_flag', 'PAN_flag', 'VoterID_flag',
#        'Driving_flag', 'Passport_flag', 'PERFORM_CNS.SCORE',
#        'PERFORM_CNS.SCORE.DESCRIPTION', 'PRI.NO.OF.ACCTS', 'PRI.ACTIVE.ACCTS',
#        'PRI.OVERDUE.ACCTS', 'PRI.CURRENT.BALANCE', 'PRI.SANCTIONED.AMOUNT',
#        'PRI.DISBURSED.AMOUNT', 'SEC.NO.OF.ACCTS', 'SEC.ACTIVE.ACCTS',
#        'SEC.OVERDUE.ACCTS', 'SEC.CURRENT.BALANCE', 'SEC.SANCTIONED.AMOUNT',
#        'SEC.DISBURSED.AMOUNT', 'PRIMARY.INSTAL.AMT', 'SEC.INSTAL.AMT',
#        'NEW.ACCTS.IN.LAST.SIX.MONTHS', 'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS',
#        'AVERAGE.ACCT.AGE', 'CREDIT.HISTORY.LENGTH', 'NO.OF_INQUIRIES',
#        'loan_default'],
#       dtype='object')

# %%
df['DisbursalDate'].head()
# Out:
# 0   2018-03-08
# 1   2018-09-26
# 2   2018-01-08
# 3   2018-10-26
# 4   2018-09-26
# Name: DisbursalDate, dtype: datetime64[ns]

# %%
import datetime

# %% [markdown]
# ## Creating the age column of customers

# %%
# df['Date.of.Birth'] = pd.to_datetime(df['Date.of.Birth'])    # 1
df['Date.of.Birth'] = df['Date.of.Birth'].where(df['Date.of.Birth'] < now, df['Date.of.Birth'] -  np.timedelta64(100, 'Y'))   # 2
df['age'] = (now - df['Date.of.Birth']).astype('<m8[Y]')

# %%
sns.distplot(df['age'])
plt.show()

# %%
df['DisbursalDate']
# Out:
# 0        2018-03-08
# 1        2018-09-26
# 2        2018-01-08
# 3        2018-10-26
# 4        2018-09-26
#             ...
# 233149   2018-10-26
# 233150   2018-10-23
# 233151   2018-10-24
# 233152   2018-09-29
# 233153   2018-10-27
# Name: DisbursalDate, Length: 233154, dtype: datetime64[ns]

# %%
df['AgeatDisbursal'] = ((df['DisbursalDate'] - df['Date.of.Birth'])/365).dt.days

# %%
sns.distplot(df['AgeatDisbursal'])

# %%
# int(df['CREDIT.HISTORY.LENGTH'][1].split()[0].replace('yrs',''))*12+ int(df['CREDIT.HISTORY.LENGTH'][1].split()[1].replace('mon',''))

# %% [markdown]
# ## Converting Credit History Length and Average Acct Age into months

# %%
def month_conversion(month):
    year = int(month.split()[0].replace('yrs',''))
    months = int(month.split()[1].replace('mon',''))
    return year*12+months

# %%
df['CREDIT.HISTORY.LENGTH'] = df['CREDIT.HISTORY.LENGTH'].apply(month_conversion)

# %%
df['AVERAGE.ACCT.AGE'].head()
# Out:
# 0     0yrs 0mon
# 1    1yrs 11mon
# 2     0yrs 0mon
# 3     0yrs 8mon
# 4     0yrs 0mon
# Name: AVERAGE.ACCT.AGE, dtype: object

# %%
df['AVERAGE.ACCT.AGE'] = df['AVERAGE.ACCT.AGE'].apply(month_conversion)

# %%
df[['CREDIT.HISTORY.LENGTH','AVERAGE.ACCT.AGE']].head()
# Out:
#    CREDIT.HISTORY.LENGTH  AVERAGE.ACCT.AGE
# 0                      0                 0
# 1                     23                23
# 2                      0                 0
# 3                     15                 8
# 4                      0                 0

# %% [markdown]
# # EDA

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Target Column - Loan Default

# %%
# Payment default in the first EMI on due date

# %%
df['loan_default'].value_counts()
# Out:
# 0    182543
# 1     50611
# Name: loan_default, dtype: int64

# %%
sns.countplot(df['loan_default'])
plt.title("loan_default")
plt.fig("loan_default.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-733297e92dbe> in <module>
#       1 sns.countplot(df['loan_default'])
#       2 plt.title("loan_default")
# ----> 3 plt.fig("loan_default.png")
#       4 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'fig'

# %%
#percentange wise

# %%
df['loan_default'].value_counts(normalize=True)*100
# Out:
# 0    78.292888
# 1    21.707112
# Name: loan_default, dtype: float64

# %%
(df['loan_default'].value_counts(normalize=True)*100).plot(kind='bar')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['manufacturer_id'])
plt.title("manufacturer_id")
plt.show()

# %% [markdown]
# manufacturer_id 86 has given the most number of vehicles

# %%
# State of disbursement

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['State_ID'])
plt.title("State_ID")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['NEW.ACCTS.IN.LAST.SIX.MONTHS'])
plt.title("NEW.ACCTS.IN.LAST.SIX.MONTHS")
plt.show()

# %%
df['NEW.ACCTS.IN.LAST.SIX.MONTHS'].value_counts(normalize=100).head()
# Out:
# 0    0.778430
# 1    0.137673
# 2    0.047243
# 3    0.019120
# 4    0.008394
# Name: NEW.ACCTS.IN.LAST.SIX.MONTHS, dtype: float64

# %% [markdown]
# It can be infered around 77% of the customers have zero new loans taken by the them in last 6 months before the  disbursment

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS'])
plt.title("DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS")
plt.show()

# %%
df['DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS'].value_counts(normalize=100).head()
# Out:
# 0    0.921961
# 1    0.064082
# 2    0.010594
# 3    0.002303
# 4    0.000592
# Name: DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS, dtype: float64

# %% [markdown]
# It can be infered that around 86% of the customers have no loans defaulted in the last six months.

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['NO.OF_INQUIRIES'])
plt.title("NO.OF_INQUIRIES")
plt.show()

# %%
df['NO.OF_INQUIRIES'].value_counts(normalize=100).head()
# Out:
# 0    0.866213
# 1    0.095581
# 2    0.023199
# 3    0.007579
# 4    0.003260
# Name: NO.OF_INQUIRIES, dtype: float64

# %% [markdown]
# Around 86% of the customers have not made any enquiries before taking the loans

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['PERFORM_CNS.SCORE.DESCRIPTION'])
plt.title("PERFORM_CNS.SCORE.DESCRIPTION")
plt.xticks(rotation=90)
plt.show()

# %%
df['PERFORM_CNS.SCORE.DESCRIPTION'].value_counts(normalize=100)
# Out:
# No Bureau History Available                                0.501600
# C-Very Low Risk                                            0.068817
# A-Very Low Risk                                            0.060578
# D-Very Low Risk                                            0.048715
# B-Very Low Risk                                            0.039463
# M-Very High Risk                                           0.037640
# F-Low Risk                                                 0.036392
# K-High Risk                                                0.035500
# H-Medium Risk                                              0.029401
# E-Low Risk                                                 0.024966
# I-Medium Risk                                              0.023834
# G-Low Risk                                                 0.017105
# Not Scored: Sufficient History Not Available               0.016148
# J-High Risk                                                0.016075
# ...

# %% [markdown]
# More than 50% data has no bureau history available.

# %%
sns.countplot(df['Employment.Type'])
plt.title("Employment.Type")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['PRI.ACTIVE.ACCTS'])
plt.title("PRI.ACTIVE.ACCTS")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['SEC.NO.OF.ACCTS'])
plt.title("SEC.NO.OF.ACCTS")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['PRI.OVERDUE.ACCTS'])
plt.title("PRI.OVERDUE.ACCTS")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['SEC.OVERDUE.ACCTS'])
plt.title("SEC.OVERDUE.ACCTS")
plt.show()

# %% [markdown]
# Most of the customers have zero primary and secondary overdue accounts

# %%
df = df.replace({'PERFORM_CNS.SCORE.DESCRIPTION':{'C-Very Low Risk':'Low', 'A-Very Low Risk':'Low',
                                                       'B-Very Low Risk':'Low', 'D-Very Low Risk':'Low',
                                                       'F-Low Risk':'Low', 'E-Low Risk':'Low', 'G-Low Risk':'Low',
                                                       'H-Medium Risk': 'Medium', 'I-Medium Risk': 'Medium',
                                                       'J-High Risk':'High', 'K-High Risk':'High','L-Very High Risk':'Very High',
                                                       'M-Very High Risk':'Very High','Not Scored: More than 50 active Accounts found':'Not Scored',
                                                       'Not Scored: Only a Guarantor':'Not Scored','Not Scored: Not Enough Info available on the customer':'Not Scored',
                                                        'Not Scored: No Activity seen on the customer (Inactive)':'Not Scored','Not Scored: No Updates available in last 36 months':'Not Scored',
                                                       'Not Scored: Sufficient History Not Available':'Not Scored', 'No Bureau History Available':'Not Scored'
                                                       }})

# %%
df['PERFORM_CNS.SCORE.DESCRIPTION'].value_counts()
# Out:
# Not Scored    129785
# Low            69022
# Medium         12412
# High           12025
# Very High       9910
# Name: PERFORM_CNS.SCORE.DESCRIPTION, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['PERFORM_CNS.SCORE.DESCRIPTION'])
plt.title("PERFORM_CNS.SCORE.DESCRIPTION")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Numerical Features

# %%
## Numerical Columns: disbursed_amount, asset_cost, ltv

# %%
#disbursed_amount = Amount of Loan disbursed

# %%
sns.distplot(df['disbursed_amount'])
plt.title("Disbursed Amount")
plt.show()

# %%
sns.boxplot(df['disbursed_amount'])
plt.title("Boxplot of Disbursed Amount")
plt.show()

# %% [markdown]
# It is heavily right skewed data.

# %%
sns.distplot(np.log(df['disbursed_amount']))
plt.title("Log Transformed Disbursed Amount")
plt.show()

# %%
# asset_cost = Cost of the Asset

# %%
sns.distplot(df['asset_cost'],color='g')
plt.title("Asset cost")
plt.show()

# %%
sns.boxplot(df['asset_cost'],color='g')
plt.title("Boxplot of Asset Amount")
plt.show()

# %% [markdown]
# It is heavily right skewed data.

# %%
### ltv = Loan to Value of the asset

# %%
sns.distplot(df['ltv'],bins=20,color='r')
plt.title("LTV-Loan To Value of the Asset")
plt.show()

# %%
sns.boxplot(df['ltv'],color='r')
plt.title("LTV-Loan To Value of the Asset")
plt.show()

# %% [markdown]
# It is heavily left skewed.

# %%
sns.distplot(np.sqrt(df['ltv']))
plt.title("Log Transformed Disbursed Amount")
plt.show()

# %%
# A disbursement, also called a cash disbursement or cash payment, refers to a wide range of payment types made in a
# specific period, including interest payments on loans and operating expenses. .
# .Disbursement can also refer to a loan payment, such as a student loan.

# %%
sns.distplot(df['PERFORM_CNS.SCORE'],bins=20)
plt.title("CNS Score")
plt.show()

# %%
sns.boxplot(df['PERFORM_CNS.SCORE'])
plt.title("CNS Score")
plt.show()

# %%
### Primary No of accounts,Secondary No of accounts

# %%
# count of total loans taken by the customer at the time of disbursement
# Primary accounts are those which the customer has taken for his personal use
# Secondary accounts are those which the customer act as a co-applicant or gaurantor

# %%
fig,axes = plt.subplots(1,2,figsize=(15,5))
sns.distplot(df['PRI.NO.OF.ACCTS'],ax=axes[0],color='r')
sns.distplot(df['SEC.NO.OF.ACCTS'],ax=axes[1])
plt.show()

# %%
### Primary Active accounts,Secondary Active accounts

# %%
fig,axes = plt.subplots(1,2,figsize=(15,5))
sns.distplot(df['PRI.ACTIVE.ACCTS'],ax=axes[0],color='r')
sns.distplot(df['SEC.ACTIVE.ACCTS'],ax=axes[1])
plt.show()

# %%
# Primary and Secondary Overdue Accounts

# %%
# count of default accounts at the time of disbursement

# %%
fig,axes = plt.subplots(1,2,figsize=(15,5))
sns.distplot(df['PRI.OVERDUE.ACCTS'],ax=axes[0],color='r')
sns.distplot(df['SEC.OVERDUE.ACCTS'],ax=axes[1])
plt.show()

# %%
# PRI.CURRENT.BALANCE

# %%
fig,axes = plt.subplots(1,2,figsize=(15,5))
sns.distplot(df['PRI.CURRENT.BALANCE'],ax=axes[0],color='r')
sns.distplot(df['SEC.CURRENT.BALANCE'],ax=axes[1])
plt.show()

# %%
# PRI.SANCTIONED.AMOUNT
# total amount that was sanctioned for all the loans at the time of disbursement

# %%
fig,axes = plt.subplots(1,2,figsize=(15,5))
sns.distplot(df['PRI.SANCTIONED.AMOUNT'],ax=axes[0],color='r')
sns.distplot(df['SEC.SANCTIONED.AMOUNT'],ax=axes[1])
plt.show()

# %%
# PRI.DISBURSED.AMOUNT
# total amount that was disbursed for all the loans at the time of disbursement

# %%
fig,axes = plt.subplots(1,2,figsize=(15,5))
sns.distplot(df['PRI.DISBURSED.AMOUNT'],ax=axes[0],color='r')
sns.distplot(df['SEC.DISBURSED.AMOUNT'],ax=axes[1])
plt.show()

# %%
# PRIMARY.INSTAL.AMT = EMI Amount of the primary loan
# SEC.INSTAL.AMT = EMI Amount of the primary loan

# %%
fig,axes = plt.subplots(1,2,figsize=(15,5))
sns.distplot(df['PRIMARY.INSTAL.AMT'],ax=axes[0],color='r')
sns.distplot(df['SEC.INSTAL.AMT'],ax=axes[1])
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(df["disbursed_amount"],df["asset_cost"],hue=df['loan_default'])
plt.show()

# %%
df[["disbursed_amount","asset_cost"]].corr()
# Out:
#                   disbursed_amount  asset_cost
# disbursed_amount          1.000000    0.752668
# asset_cost                0.752668    1.000000

# %% [markdown]
# Strong correlation between disbursed amount and asset cost

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(df["disbursed_amount"],df["ltv"],hue=df['loan_default'],markers="x")
plt.show()

# %%
df[["disbursed_amount","ltv"]].corr()
# Out:
#                   disbursed_amount       ltv
# disbursed_amount          1.000000  0.376747
# ltv                       0.376747  1.000000

# %% [markdown]
# Moderate correlation between disbursed amount and asset cost

# %% [markdown]
# ## Employment Type Vs Loan Default

# %%
a = pd.crosstab(df['Employment.Type'],df['loan_default'],normalize="index")

# %%
a
# Out:
# loan_default            0         1
# Employment.Type
# Missing          0.785407  0.214593
# Salaried         0.796542  0.203458
# Self employed    0.772343  0.227657

# %%
a.plot(kind='bar')
plt.show()

# %%
a.plot(kind = 'bar', stacked = True)
plt.show()

# %%
b = pd.crosstab(df['PERFORM_CNS.SCORE.DESCRIPTION'],df['loan_default'])

# %%
b.plot.bar(figsize=(12,6))
plt.show()

# %%
pd.crosstab(df['State_ID'],df['loan_default']).plot.bar(figsize=(15,5))
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(df[['disbursed_amount', 'asset_cost', 'ltv', 'PERFORM_CNS.SCORE',
'PRI.CURRENT.BALANCE','PRI.DISBURSED.AMOUNT', 'PRIMARY.INSTAL.AMT']])

# %%
##################################################################################

# %%
df.columns
# Out:
# Index(['UniqueID', 'disbursed_amount', 'asset_cost', 'ltv', 'branch_id',
#        'supplier_id', 'manufacturer_id', 'Current_pincode_ID', 'Date.of.Birth',
#        'Employment.Type', 'DisbursalDate', 'State_ID', 'Employee_code_ID',
#        'MobileNo_Avl_Flag', 'Aadhar_flag', 'PAN_flag', 'VoterID_flag',
#        'Driving_flag', 'Passport_flag', 'PERFORM_CNS.SCORE',
#        'PERFORM_CNS.SCORE.DESCRIPTION', 'PRI.NO.OF.ACCTS', 'PRI.ACTIVE.ACCTS',
#        'PRI.OVERDUE.ACCTS', 'PRI.CURRENT.BALANCE', 'PRI.SANCTIONED.AMOUNT',
#        'PRI.DISBURSED.AMOUNT', 'SEC.NO.OF.ACCTS', 'SEC.ACTIVE.ACCTS',
#        'SEC.OVERDUE.ACCTS', 'SEC.CURRENT.BALANCE', 'SEC.SANCTIONED.AMOUNT',
#        'SEC.DISBURSED.AMOUNT', 'PRIMARY.INSTAL.AMT', 'SEC.INSTAL.AMT',
#        'NEW.ACCTS.IN.LAST.SIX.MONTHS', 'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS',
#        'AVERAGE.ACCT.AGE', 'CREDIT.HISTORY.LENGTH', 'NO.OF_INQUIRIES',
#        'loan_default', 'TODAY', 'AGE'],
#       dtype='object')

# %%
df.select_dtypes(include=['int64','float64']).columns
# Out:
# Index(['disbursed_amount', 'asset_cost', 'ltv', 'supplier_id',
#        'PERFORM_CNS.SCORE', 'PRI.NO.OF.ACCTS', 'PRI.ACTIVE.ACCTS',
#        'PRI.OVERDUE.ACCTS', 'PRI.CURRENT.BALANCE', 'PRI.SANCTIONED.AMOUNT',
#        'PRI.DISBURSED.AMOUNT', 'SEC.NO.OF.ACCTS', 'SEC.ACTIVE.ACCTS',
#        'SEC.OVERDUE.ACCTS', 'SEC.CURRENT.BALANCE', 'SEC.SANCTIONED.AMOUNT',
#        'SEC.DISBURSED.AMOUNT', 'PRIMARY.INSTAL.AMT', 'SEC.INSTAL.AMT',
#        'NEW.ACCTS.IN.LAST.SIX.MONTHS', 'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS',
#        'AVERAGE.ACCT.AGE', 'CREDIT.HISTORY.LENGTH', 'NO.OF_INQUIRIES', 'age',
#        'AgeatDisbursal'],
#       dtype='object')

# %%
df[["disbursed_amount","asset_cost"]].corr()
# Out:
#                   disbursed_amount  asset_cost
# disbursed_amount          1.000000    0.752668
# asset_cost                0.752668    1.000000

# %% [markdown]
# ### Disbursed amount and asset cost seems to be positively correlated.

# %%
from scipy.stats import ttest_ind

# %% [markdown]
# ## H0:Mean of 0 == Mean of 1
# ## H1:Mean of 0!= Mean of 1

# %%
loan_0 = df[df["loan_default"]==0]
loan_1 = df[df["loan_default"]==1]

# %%
ttest_ind(loan_0["ltv"],loan_1["ltv"])
# Out:
# Ttest_indResult(statistic=-47.65077542766104, pvalue=0.0)

# %% [markdown]
# p-value is less than 0.05 it failed to reject the null hypothesis which shows it is significant feature.

# %%
df['Current_pincode_ID'].head()
# Out:
# 0    1441
# 1    1502
# 2    1497
# 3    1501
# 4    1495
# Name: Current_pincode_ID, dtype: category
# Categories (6698, int64): [1, 2, 3, 4, ..., 7342, 7343, 7344, 7345]

# %%
df['Current_pincode_ID'].nunique()
# Out:
# 6698

# %%
pd.to_datetime(df['Date.of.Birth'])
# Out:
# 0        1984-01-01
# 1        1985-07-31
# 2        1985-08-24
# 3        1993-12-30
# 4        1977-09-12
#             ...
# 233149   1988-01-08
# 233150   1988-05-12
# 233151   1976-01-06
# 233152   1994-03-26
# 233153   1984-02-18
# Name: Date.of.Birth, Length: 233154, dtype: datetime64[ns]

# %%
#State_ID = State of disbursement
df['State_ID'].value_counts()
#check for categor/numer
# Out:
# 4     44870
# 3     34078
# 6     33505
# 13    17884
# 9     16022
# 8     14197
# 5     10177
# 14     9414
# 1      8936
# 7      6786
# 11     6721
# 18     5412
# 15     5049
# 12     4210
# 2      4160
# 17     3991
# 10     3605
# 16     2685
# 19     1035
# 20      185
# 21      156
# 22       76
# Name: State_ID, dtype: int64

# %%
#PERFORM_CNS.SCORE.DESCRIPTION = Bureau score description
df['PERFORM_CNS.SCORE.DESCRIPTION'].value_counts()
# Out:
# Not Scored    129785
# Low            69022
# Medium         12412
# High           12025
# Very High       9910
# Name: PERFORM_CNS.SCORE.DESCRIPTION, dtype: int64

# %% [markdown]
# There are subcategories withing the perform cns score description

# %%
#CREDIT.HISTORY.LENGTH = Time since first loan
df['CREDIT.HISTORY.LENGTH'].value_counts()
# Out:
# 0yrs 0mon     119127
# 0yrs 6mon       4761
# 2yrs 1mon       4745
# 0yrs 7mon       4017
# 2yrs 0mon       3833
#                ...
# 25yrs 8mon         1
# 25yrs 0mon         1
# 19yrs 1mon         1
# 19yrs 0mon         1
# 23yrs 1mon         1
# Name: CREDIT.HISTORY.LENGTH, Length: 294, dtype: int64

# %% [markdown]
# ### Mobile, PAN, VoterID, Passport features

# %%
df['MobileNo_Avl_Flag'].value_counts()
# Out:
# 1    233154
# Name: MobileNo_Avl_Flag, dtype: int64

# %% [markdown]
# All the customers mobile numbers are shared by the customer to the bank.

# %%
df['PAN_flag'].value_counts()
# Out:
# 0    215533
# 1     17621
# Name: PAN_flag, dtype: int64

# %%
df['VoterID_flag'].value_counts()
# Out:
# 0    199360
# 1     33794
# Name: VoterID_flag, dtype: int64

# %%
df['Driving_flag'].value_counts()
# Out:
# 0    227735
# 1      5419
# Name: Driving_flag, dtype: int64

# %%
df['Passport_flag'].value_counts()
# Out:
# 0    232658
# 1       496
# Name: Passport_flag, dtype: int64

# %% [markdown]
# ### CNS Score

# %%
# A credit bureau score is a statistical indicator of the likelihood that a customer will
# default on a payment over the next year, given that customer’s historical behavior as evidenced by credit bureau data.
# Credit bureau scores are an invaluable tool for improving the analytical powers of credit risk managers, and implementing
# automated decision policies

# %%
# Bureau Score
df['PERFORM_CNS.SCORE'].value_counts()
# Out:
# 0      116950
# 300      8776
# 738      8662
# 825      7393
# 15       3765
#         ...
# 838         1
# 862         1
# 822         1
# 847         1
# 867         1
# Name: PERFORM_CNS.SCORE, Length: 573, dtype: int64

# %%
# NEW.ACCTS.IN.LAST.SIX.MONTHS =New loans taken by the customer in last 6 months before the disbursment

# %%
df['NEW.ACCTS.IN.LAST.SIX.MONTHS'].value_counts()
# Out:
# 0     181494
# 1      32099
# 2      11015
# 3       4458
# 4       1957
# 5        964
# 6        480
# 7        302
# 8        147
# 9         79
# 10        55
# 11        31
# 12        20
# 13        15
# 14        11
# 16         6
# 17         6
# 20         3
# 15         2
# 18         2
# 19         2
# 23         2
# 28         1
# 21         1
# 22         1
# 35         1
# Name: NEW.ACCTS.IN.LAST.SIX.MONTHS, dtype: int64

# %%
# DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS = Loans defaulted in the last 6 months

# %%
df['DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS'].value_counts()
# Out:
# 0     214959
# 1      14941
# 2       2470
# 3        537
# 4        138
# 5         58
# 6         20
# 7         13
# 8          7
# 12         3
# 11         3
# 10         2
# 9          2
# 20         1
# Name: DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS, dtype: int64

# %%
# AVERAGE.ACCT.AGE = Average loan tenure

# %%
df['AVERAGE.ACCT.AGE']
# Out:
# 0          0yrs 0mon
# 1         1yrs 11mon
# 2          0yrs 0mon
# 3          0yrs 8mon
# 4          0yrs 0mon
#              ...
# 233149     1yrs 9mon
# 233150     0yrs 6mon
# 233151     0yrs 0mon
# 233152     0yrs 0mon
# 233153     0yrs 0mon
# Name: AVERAGE.ACCT.AGE, Length: 233154, dtype: object

# %%
# CREDIT.HISTORY.LENGTH = Time since first loan

# %%
df['CREDIT.HISTORY.LENGTH']
# Out:
# 0          0yrs 0mon
# 1         1yrs 11mon
# 2          0yrs 0mon
# 3          1yrs 3mon
# 4          0yrs 0mon
#              ...
# 233149     3yrs 3mon
# 233150     0yrs 6mon
# 233151     0yrs 0mon
# 233152     0yrs 0mon
# 233153     0yrs 0mon
# Name: CREDIT.HISTORY.LENGTH, Length: 233154, dtype: object
